# %% [markdown]
# This is a simple example using Transfer Learning for an image recognition problem.

# %% [markdown]
# # Imports de Libs

# %%
# General Libs
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
#from tensorflow.keras.applications.efficientnet import EfficientNetB2, preprocess_input
#from tensorflow.keras.applications.efficientnet_v2 import EfficientNetV2L, preprocess_input
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Lendo o dataset

# %%
# Alguns parâmetros para leitura do dataset
im_shape = (299,299)

TRAINING_DIR = '../input/amazon-fruits-small/ds_frutas_am/train'
TEST_DIR = '../input/amazon-fruits-small/ds_frutas_am/test'

seed = 10

BATCH_SIZE = 16

# %%
#Using keras ImageGenerator and flow_from_directoty

# With augmentation
data_generator = ImageDataGenerator(
        validation_split=0.2,
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        preprocessing_function=preprocess_input,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest')
val_data_generator = ImageDataGenerator(preprocessing_function=preprocess_input,validation_split=0.2)

# %%
# Generator para parte train
train_generator = data_generator.flow_from_directory(TRAINING_DIR, target_size=im_shape, shuffle=True, seed=seed,
                                                     class_mode='categorical', batch_size=BATCH_SIZE, subset="training")
# Generator para parte validação
validation_generator = val_data_generator.flow_from_directory(TRAINING_DIR, target_size=im_shape, shuffle=False, seed=seed,
                                                     class_mode='categorical', batch_size=BATCH_SIZE, subset="validation")

# Generator para dataset de teste
test_generator = ImageDataGenerator(preprocessing_function=preprocess_input)
test_generator = test_generator.flow_from_directory(TEST_DIR, target_size=im_shape, shuffle=False, seed=seed,
                                                     class_mode='categorical', batch_size=BATCH_SIZE)

nb_train_samples = train_generator.samples
nb_validation_samples = validation_generator.samples
nb_test_samples = test_generator.samples
classes = list(train_generator.class_indices.keys())
print('Classes: '+str(classes))
num_classes  = len(classes)
# Out:
# Found 72 images belonging to 6 classes.
# Found 18 images belonging to 6 classes.
# Found 30 images belonging to 6 classes.
# Classes: ['acai', 'cupuacu', 'graviola', 'guarana', 'pupunha', 'tucuma']

# %%
# Visualizando alguns exemplos do dataset por meio do Generator criado
plt.figure(figsize=(15,15))
for i in range(9):
    #gera subfigures
    plt.subplot(330 + 1 + i)
    batch = (train_generator.next()[0]+1)/2*255
    image = batch[0].astype('uint8')
    plt.imshow(image)
plt.show()

# %% [markdown]
# # Transfer Learning from a Deep Model

# %%
base_model = InceptionResNetV2(weights='imagenet',include_top=False, input_shape=(im_shape[0], im_shape[1], 3))
# Freezing pretrained layers
base_model.trainable = False

model = Sequential()
model.add(base_model)
model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

optimizer = Adam()
model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_resnet_v2 (Functio (None, 8, 8, 1536)        54336736
# _________________________________________________________________
# flatten (Flatten)            (None, 98304)             0
# _________________________________________________________________
# dense (Dense)                (None, 100)               9830500
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 606
# =================================================================
# Total params: 64,167,842
# Trainable params: 9,831,106
# Non-trainable params: 54,336,736
# _________________________________________________________________

# %%
epochs = 100

# Saving the best model
callbacks_list = [
    keras.callbacks.ModelCheckpoint(
        filepath='model.h5',
        monitor='val_loss', save_best_only=True, verbose=1),
    keras.callbacks.EarlyStopping(monitor='val_loss', patience=50,verbose=1)
]

history = model.fit(
        train_generator,
        steps_per_epoch=nb_train_samples // BATCH_SIZE,
        epochs=epochs,
        callbacks = callbacks_list,
        validation_data=validation_generator,
        verbose = 1,
        validation_steps=nb_validation_samples // BATCH_SIZE)
# Out:
# Epoch 1/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0315 - accuracy: 0.9844
# Epoch 00001: val_loss improved from inf to 0.18438, saving model to model.h5
# 4/4 [==============================] - 3s 756ms/step - loss: 0.0315 - accuracy: 0.9844 - val_loss: 0.1844 - val_accuracy: 0.9375
# Epoch 2/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0208 - accuracy: 1.0000
# Epoch 00002: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 0.2018 - val_accuracy: 0.8750
# Epoch 3/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 1.0000
# Epoch 00003: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 262ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.2395 - val_accuracy: 0.8125
# Epoch 4/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0211 - accuracy: 0.9821
# Epoch 00004: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 313ms/step - loss: 0.0211 - accuracy: 0.9821 - val_loss: 0.2443 - val_accuracy: 0.8125
# Epoch 5/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0371 - accuracy: 0.9844
# Epoch 00005: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 312ms/step - loss: 0.0371 - accuracy: 0.9844 - val_loss: 0.2131 - val_accuracy: 0.8125
# Epoch 6/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0304 - accuracy: 1.0000
# Epoch 00006: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 255ms/step - loss: 0.0304 - accuracy: 1.0000 - val_loss: 0.2208 - val_accuracy: 0.9375
# Epoch 7/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0737 - accuracy: 0.9643
# Epoch 00007: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 253ms/step - loss: 0.0737 - accuracy: 0.9643 - val_loss: 0.2270 - val_accuracy: 0.9375
# Epoch 8/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0314 - accuracy: 0.9844
# Epoch 00008: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 306ms/step - loss: 0.0314 - accuracy: 0.9844 - val_loss: 0.2873 - val_accuracy: 0.7500
# Epoch 9/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 1.0000
# Epoch 00009: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 256ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.4579 - val_accuracy: 0.7500
# Epoch 10/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0104 - accuracy: 1.0000
# Epoch 00010: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 261ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.5647 - val_accuracy: 0.7500
# Epoch 11/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0379 - accuracy: 0.9821
# Epoch 00011: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 267ms/step - loss: 0.0379 - accuracy: 0.9821 - val_loss: 0.3781 - val_accuracy: 0.7500
# Epoch 12/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0218 - accuracy: 1.0000
# Epoch 00012: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 250ms/step - loss: 0.0218 - accuracy: 1.0000 - val_loss: 0.2517 - val_accuracy: 0.8125
# Epoch 13/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0149 - accuracy: 1.0000
# Epoch 00013: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 307ms/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.2071 - val_accuracy: 0.9375
# Epoch 14/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0171 - accuracy: 1.0000
# Epoch 00014: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 259ms/step - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.2025 - val_accuracy: 0.8750
# Epoch 15/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0140 - accuracy: 1.0000
# Epoch 00015: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 262ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.2045 - val_accuracy: 0.8750
# Epoch 16/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 1.0000
# Epoch 00016: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 305ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.2042 - val_accuracy: 0.8750
# Epoch 17/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0121 - accuracy: 1.0000
# Epoch 00017: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 253ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.2428 - val_accuracy: 0.8750
# Epoch 18/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 00018: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 317ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.3237 - val_accuracy: 0.8125
# Epoch 19/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 1.0000
# Epoch 00019: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 267ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.4498 - val_accuracy: 0.7500
# Epoch 20/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 1.0000
# Epoch 00020: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.4112 - val_accuracy: 0.7500
# Epoch 21/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 1.0000
# Epoch 00021: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 300ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.3157 - val_accuracy: 0.8125
# Epoch 22/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 1.0000
# Epoch 00022: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 259ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.3880 - val_accuracy: 0.8125
# Epoch 23/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 1.0000
# Epoch 00023: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 320ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.4710 - val_accuracy: 0.8125
# Epoch 24/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0784 - accuracy: 0.9531
# Epoch 00024: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 333ms/step - loss: 0.0784 - accuracy: 0.9531 - val_loss: 0.3767 - val_accuracy: 0.8125
# Epoch 25/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 1.0000
# Epoch 00025: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 243ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.6995 - val_accuracy: 0.8125
# Epoch 26/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0200 - accuracy: 1.0000
# Epoch 00026: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 315ms/step - loss: 0.0200 - accuracy: 1.0000 - val_loss: 0.6845 - val_accuracy: 0.8125
# Epoch 27/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0162 - accuracy: 1.0000
# Epoch 00027: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 246ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.4724 - val_accuracy: 0.8125
# Epoch 28/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 1.0000
# Epoch 00028: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 259ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.2923 - val_accuracy: 0.8125
# Epoch 29/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0560 - accuracy: 0.9688
# Epoch 00029: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0560 - accuracy: 0.9688 - val_loss: 0.2115 - val_accuracy: 0.8750
# Epoch 30/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9821
# Epoch 00030: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 259ms/step - loss: 0.0263 - accuracy: 0.9821 - val_loss: 0.2455 - val_accuracy: 0.8125
# Epoch 31/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 00031: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 242ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.3958 - val_accuracy: 0.8125
# Epoch 32/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0458 - accuracy: 0.9688
# Epoch 00032: val_loss did not improve from 0.18438
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0458 - accuracy: 0.9688 - val_loss: 0.2643 - val_accuracy: 0.8750
# Epoch 33/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0773 - accuracy: 0.9821
# Epoch 00033: val_loss improved from 0.18438 to 0.14866, saving model to model.h5
# 4/4 [==============================] - 3s 641ms/step - loss: 0.0773 - accuracy: 0.9821 - val_loss: 0.1487 - val_accuracy: 0.9375
# Epoch 34/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 00034: val_loss did not improve from 0.14866
# 4/4 [==============================] - 1s 258ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.1646 - val_accuracy: 0.8750
# Epoch 35/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 1.0000
# Epoch 00035: val_loss did not improve from 0.14866
# 4/4 [==============================] - 1s 247ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.2627 - val_accuracy: 0.8125
# Epoch 36/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 1.0000
# Epoch 00036: val_loss did not improve from 0.14866
# 4/4 [==============================] - 1s 253ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.3374 - val_accuracy: 0.8750
# Epoch 37/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 00037: val_loss did not improve from 0.14866
# 4/4 [==============================] - 1s 261ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.4380 - val_accuracy: 0.8125
# Epoch 38/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 1.0000
# Epoch 00038: val_loss did not improve from 0.14866
# 4/4 [==============================] - 1s 255ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.4670 - val_accuracy: 0.8125
# Epoch 39/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0821 - accuracy: 0.9688
# Epoch 00039: val_loss did not improve from 0.14866
# 4/4 [==============================] - 1s 297ms/step - loss: 0.0821 - accuracy: 0.9688 - val_loss: 0.2323 - val_accuracy: 0.8750
# Epoch 40/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0233 - accuracy: 0.9844
# Epoch 00040: val_loss did not improve from 0.14866
# 4/4 [==============================] - 1s 296ms/step - loss: 0.0233 - accuracy: 0.9844 - val_loss: 0.1825 - val_accuracy: 0.8750
# Epoch 41/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 1.0000
# Epoch 00041: val_loss did not improve from 0.14866
# 4/4 [==============================] - 1s 241ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.2197 - val_accuracy: 0.8750
# Epoch 42/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 00042: val_loss did not improve from 0.14866
# 4/4 [==============================] - 1s 242ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.3348 - val_accuracy: 0.8750
# Epoch 43/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 00043: val_loss did not improve from 0.14866
# 4/4 [==============================] - 1s 367ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.4328 - val_accuracy: 0.8750
# Epoch 44/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 1.0000
# Epoch 00044: val_loss did not improve from 0.14866
# 4/4 [==============================] - 1s 301ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.5869 - val_accuracy: 0.8125
# Epoch 45/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0121 - accuracy: 1.0000
# Epoch 00045: val_loss did not improve from 0.14866
# 4/4 [==============================] - 1s 282ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.6384 - val_accuracy: 0.7500
# Epoch 46/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 00046: val_loss did not improve from 0.14866
# 4/4 [==============================] - 1s 258ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.5719 - val_accuracy: 0.7500
# Epoch 47/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0165 - accuracy: 1.0000
# Epoch 00047: val_loss did not improve from 0.14866
# 4/4 [==============================] - 1s 297ms/step - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.4273 - val_accuracy: 0.8125
# Epoch 48/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 1.0000
# Epoch 00048: val_loss did not improve from 0.14866
# 4/4 [==============================] - 1s 270ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.2993 - val_accuracy: 0.8750
# Epoch 49/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 1.0000
# Epoch 00049: val_loss did not improve from 0.14866
# 4/4 [==============================] - 1s 243ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.2020 - val_accuracy: 0.8750
# Epoch 50/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 1.0000
# Epoch 00050: val_loss did not improve from 0.14866
# 4/4 [==============================] - 1s 240ms/step - loss: 0.0250 - accuracy: 1.0000 - val_loss: 0.2986 - val_accuracy: 0.8750
# Epoch 51/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0099 - accuracy: 1.0000
# Epoch 00051: val_loss did not improve from 0.14866
# 4/4 [==============================] - 1s 251ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.4201 - val_accuracy: 0.8125
# Epoch 52/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0409 - accuracy: 0.9821
# Epoch 00052: val_loss did not improve from 0.14866
# 4/4 [==============================] - 1s 251ms/step - loss: 0.0409 - accuracy: 0.9821 - val_loss: 0.2735 - val_accuracy: 0.8750
# Epoch 53/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 00053: val_loss did not improve from 0.14866
# 4/4 [==============================] - 1s 246ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1646 - val_accuracy: 0.9375
# Epoch 54/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0495 - accuracy: 0.9821
# Epoch 00054: val_loss improved from 0.14866 to 0.12995, saving model to model.h5
# 4/4 [==============================] - 3s 644ms/step - loss: 0.0495 - accuracy: 0.9821 - val_loss: 0.1300 - val_accuracy: 0.9375
# Epoch 55/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0148 - accuracy: 1.0000
# Epoch 00055: val_loss did not improve from 0.12995
# 4/4 [==============================] - 1s 241ms/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.1433 - val_accuracy: 0.9375
# Epoch 56/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 00056: val_loss did not improve from 0.12995
# 4/4 [==============================] - 1s 320ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.1976 - val_accuracy: 0.8750
# Epoch 57/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 00057: val_loss did not improve from 0.12995
# 4/4 [==============================] - 1s 300ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.2266 - val_accuracy: 0.8750
# Epoch 58/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 1.0000
# Epoch 00058: val_loss did not improve from 0.12995
# 4/4 [==============================] - 1s 293ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.2110 - val_accuracy: 0.8750
# Epoch 59/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 1.0000
# Epoch 00059: val_loss did not improve from 0.12995
# 4/4 [==============================] - 1s 241ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.1426 - val_accuracy: 0.8750
# Epoch 60/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 00060: val_loss improved from 0.12995 to 0.09804, saving model to model.h5
# 4/4 [==============================] - 3s 756ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0980 - val_accuracy: 1.0000
# Epoch 61/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 1.0000
# Epoch 00061: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 284ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0996 - val_accuracy: 0.9375
# Epoch 62/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 00062: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 243ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9375
# Epoch 63/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 1.0000
# Epoch 00063: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 271ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1799 - val_accuracy: 0.8750
# Epoch 64/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 00064: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 256ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2719 - val_accuracy: 0.8750
# Epoch 65/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 1.0000
# Epoch 00065: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 257ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.2466 - val_accuracy: 0.8750
# Epoch 66/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 00066: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 248ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2134 - val_accuracy: 0.8750
# Epoch 67/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 00067: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 255ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1950 - val_accuracy: 0.9375
# Epoch 68/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 00068: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 248ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.1760 - val_accuracy: 0.8750
# Epoch 69/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 00069: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 243ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1732 - val_accuracy: 0.8750
# Epoch 70/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 00070: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.1718 - val_accuracy: 0.8750
# Epoch 71/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 00071: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 268ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1720 - val_accuracy: 0.8750
# Epoch 72/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 00072: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 268ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1773 - val_accuracy: 0.8750
# Epoch 73/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 00073: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 298ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1879 - val_accuracy: 0.8125
# Epoch 74/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 00074: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 300ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1984 - val_accuracy: 0.8125
# Epoch 75/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000
# Epoch 00075: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 307ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1954 - val_accuracy: 0.8125
# Epoch 76/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 1.0000
# Epoch 00076: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 300ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.1974 - val_accuracy: 0.8125
# Epoch 77/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00077: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 306ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.8125
# Epoch 78/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9821
# Epoch 00078: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 310ms/step - loss: 0.0229 - accuracy: 0.9821 - val_loss: 0.2791 - val_accuracy: 0.8750
# Epoch 79/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 1.0000
# Epoch 00079: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 303ms/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.5170 - val_accuracy: 0.8750
# Epoch 80/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 00080: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 255ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.6473 - val_accuracy: 0.8750
# Epoch 81/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 00081: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 316ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.6813 - val_accuracy: 0.8750
# Epoch 82/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0411 - accuracy: 0.9688
# Epoch 00082: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 297ms/step - loss: 0.0411 - accuracy: 0.9688 - val_loss: 0.4229 - val_accuracy: 0.7500
# Epoch 83/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 1.0000
# Epoch 00083: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 312ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.0781 - val_accuracy: 0.7500
# Epoch 84/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0187 - accuracy: 1.0000
# Epoch 00084: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 254ms/step - loss: 0.0187 - accuracy: 1.0000 - val_loss: 1.5205 - val_accuracy: 0.6875
# Epoch 85/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0555 - accuracy: 0.9821
# Epoch 00085: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 243ms/step - loss: 0.0555 - accuracy: 0.9821 - val_loss: 0.3795 - val_accuracy: 0.8750
# Epoch 86/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0470 - accuracy: 0.9821
# Epoch 00086: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 248ms/step - loss: 0.0470 - accuracy: 0.9821 - val_loss: 0.7727 - val_accuracy: 0.8125
# Epoch 87/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0578 - accuracy: 0.9643
# Epoch 00087: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 245ms/step - loss: 0.0578 - accuracy: 0.9643 - val_loss: 0.4027 - val_accuracy: 0.7500
# Epoch 88/100
# 4/4 [==============================] - ETA: 0s - loss: 0.2697 - accuracy: 0.9643
# Epoch 00088: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 248ms/step - loss: 0.2697 - accuracy: 0.9643 - val_loss: 1.6379 - val_accuracy: 0.7500
# Epoch 89/100
# 4/4 [==============================] - ETA: 0s - loss: 0.2572 - accuracy: 0.9286
# Epoch 00089: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 298ms/step - loss: 0.2572 - accuracy: 0.9286 - val_loss: 1.0847 - val_accuracy: 0.7500
# Epoch 90/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0320 - accuracy: 0.9821
# Epoch 00090: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 253ms/step - loss: 0.0320 - accuracy: 0.9821 - val_loss: 0.7262 - val_accuracy: 0.8125
# Epoch 91/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0235 - accuracy: 0.9821
# Epoch 00091: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 265ms/step - loss: 0.0235 - accuracy: 0.9821 - val_loss: 0.5727 - val_accuracy: 0.8750
# Epoch 92/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0455 - accuracy: 0.9821
# Epoch 00092: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 253ms/step - loss: 0.0455 - accuracy: 0.9821 - val_loss: 0.8513 - val_accuracy: 0.6875
# Epoch 93/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0770 - accuracy: 0.9643
# Epoch 00093: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 259ms/step - loss: 0.0770 - accuracy: 0.9643 - val_loss: 0.7398 - val_accuracy: 0.6250
# Epoch 94/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0207 - accuracy: 1.0000
# Epoch 00094: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0207 - accuracy: 1.0000 - val_loss: 0.3337 - val_accuracy: 0.8750
# Epoch 95/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 1.0000
# Epoch 00095: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 301ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.2732 - val_accuracy: 0.9375
# Epoch 96/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 00096: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 300ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.3077 - val_accuracy: 0.8750
# Epoch 97/100
# 4/4 [==============================] - ETA: 0s - loss: 0.1173 - accuracy: 0.9643
# Epoch 00097: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 309ms/step - loss: 0.1173 - accuracy: 0.9643 - val_loss: 0.2811 - val_accuracy: 0.9375
# Epoch 98/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0430 - accuracy: 0.9821
# Epoch 00098: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 311ms/step - loss: 0.0430 - accuracy: 0.9821 - val_loss: 0.5029 - val_accuracy: 0.8125
# Epoch 99/100
# 4/4 [==============================] - ETA: 0s - loss: 0.0173 - accuracy: 1.0000
# Epoch 00099: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 247ms/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.7556 - val_accuracy: 0.7500
# Epoch 100/100
# 4/4 [==============================] - ETA: 0s - loss: 0.1517 - accuracy: 0.9821
# Epoch 00100: val_loss did not improve from 0.09804
# 4/4 [==============================] - 1s 251ms/step - loss: 0.1517 - accuracy: 0.9821 - val_loss: 0.7178 - val_accuracy: 0.8125

# %%
#Vamos ver como foi o treino?

fig, ax = plt.subplots(1,2, figsize=(16,8))
ax[0].plot(history.history['loss'], color='b', label="Training loss")
ax[0].plot(history.history['val_loss'], color='r', label="validation loss",axes =ax[0])
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(history.history['accuracy'], color='b', label="Training accuracy")
ax[1].plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
legend = ax[1].legend(loc='best', shadow=True)

# %%
from tensorflow.keras.models import load_model
# Load the best saved model
model = load_model('model.h5')

# %%
#Detalhes do modelo
#model.summary()

# %%
# Using the validation dataset
score = model.evaluate_generator(validation_generator)
print('Val loss:', score[0])
print('Val accuracy:', score[1])
# Out:
# Val loss: 0.1290968507528305
# Val accuracy: 0.9444444179534912

# %%
# Using the test dataset
score = model.evaluate_generator(test_generator)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.695531964302063
# Test accuracy: 0.8333333134651184

# %%
# Some reports
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import numpy as np

#Confution Matrix and Classification Report
Y_pred = model.predict_generator(test_generator)#, nb_test_samples // BATCH_SIZE, workers=1)
y_pred = np.argmax(Y_pred, axis=1)
target_names = classes

#Confution Matrix
cm = confusion_matrix(test_generator.classes, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)

# %%
print('Classification Report')
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#         acai       1.00      0.60      0.75         5
#      cupuacu       1.00      0.80      0.89         5
#     graviola       1.00      1.00      1.00         5
#      guarana       0.80      0.80      0.80         5
#      pupunha       0.62      1.00      0.77         5
#       tucuma       0.80      0.80      0.80         5
#
#     accuracy                           0.83        30
#    macro avg       0.87      0.83      0.83        30
# weighted avg       0.87      0.83      0.83        30
